# %%
#To print all the outputs in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
tokyo = pd.read_excel('Fellow Project - Tokyo Data.xlsx')

# %%
tokyo.head()
# Out:
#   Competition_Name           Competitor Event_Gender   Event_ID Event_Name  \
# 0    Olympic Games  A. Murray/Salisbury          Men  100010265    Doubles
# 1    Olympic Games          A'Ja Wilson        Women  200010983       Team
# 2    Olympic Games      Aaliyah Edwards        Women  200010983       Team
# 3    Olympic Games          Aaron Brown          Men  100009572       200m
# 4    Olympic Games          Aaron Brown          Men  100009572       200m
#
#    Sport_Name  NOC       NOC_Name  Person_ID Result Result_Type  Sport_ID  \
# 0      Tennis  GBR  Great Britain         -1    NaN         NaN       105
# 1  Basketball  USA  United States    1192461    NaN         NaN       107
# 2  Basketball  CAN         Canada    1828248    NaN         NaN       107
# 3   Athletics  CAN         Canada     798318   20.2        Time       106
# 4   Athletics  CAN         Canada     798318   20.2        Time       106
#
#      Team_ID                                          Team_Mbrs  \
# 0  200140186                       Murray, Andy; Salisbury, Joe
# 1  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 2  100000355  Achonwa, Natalie; Alexander, Kayla; Amihere, L...
# 3  400000309                                                NaN
# 4  400000309                                                NaN
#
#   Team_Member_Select  Person_Age_Days  Final Rank
# 0                 No              NaN         5.0
# 1                Yes              NaN         1.0
# 2                Yes              NaN         9.0
# 3                 No          10661.0         6.0
# 4                Yes          10661.0         6.0

# %%
tokyo.shape
# Out:
# (38643, 17)

# %%
#Will drop duplicates
df = tokyo.drop_duplicates()

# %%
df.shape
# Out:
# (38643, 17)

# %%
#Checking null values to assess data quality
df.isna().sum()
# Out:
# Competition_Name          0
# Competitor                0
# Event_Gender              0
# Event_ID                  0
# Event_Name                0
# Sport_Name                0
# NOC                       0
# NOC_Name                  0
# Person_ID                 0
# Result                13628
# Result_Type           11071
# Sport_ID                  0
# Team_ID                   0
# Team_Mbrs             27769
# Team_Member_Select        0
# Person_Age_Days       10879
# Final Rank             1166
# dtype: int64

# %% [markdown]
# ### 1. Deleting Team_Member_Select column

# %% [markdown]
# ##### The Team_Member_Select column is adding duplicate records in the dataset.
# ##### Here, Aaron Brown's entries for the 200m event are duplicated, differing only in the Team_Member_Select value (No vs. Yes). This redundancy can lead to inaccurate analysis so we will remove this column.

# %%
df.iloc[3:5,]
# Out:
#   Competition_Name   Competitor Event_Gender   Event_ID Event_Name Sport_Name  \
# 3    Olympic Games  Aaron Brown          Men  100009572       200m  Athletics
# 4    Olympic Games  Aaron Brown          Men  100009572       200m  Athletics
#
#    NOC NOC_Name  Person_ID Result Result_Type  Sport_ID    Team_ID Team_Mbrs  \
# 3  CAN   Canada     798318   20.2        Time       106  400000309       NaN
# 4  CAN   Canada     798318   20.2        Time       106  400000309       NaN
#
#   Team_Member_Select  Person_Age_Days  Final Rank
# 3                 No          10661.0         6.0
# 4                Yes          10661.0         6.0

# %%
df.drop(columns='Team_Member_Select', inplace=True)

# %%
df.shape
# Out:
# (38643, 16)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (24759, 16)

# %%
#Dataset has shrunk considerably

# %% [markdown]
# ## 2. Standardizing Person_Age_Days across common Person_IDs

# %% [markdown]
# ##### The dataset shows inconsistency in the Person_Age_Days column for Person_ID 1184868. The age values vary or are missing across different records for the same person, as illustrated below

# %%
df[df['Person_ID']==1184868][['Person_ID', 'Person_Age_Days']]
# Out:
#       Person_ID  Person_Age_Days
# 3664    1184868           9115.0
# 3666    1184868           9113.0
# 3668    1184868              NaN
# 3669    1184868              NaN
# 3670    1184868           9116.0
# 3672    1184868              NaN

# %% [markdown]
# ##### To standardize this dataset, for each Person_ID, we will fill Person_Age_Days with first non-null value

# %%
def first_non_null(series):
    return series.dropna().iloc[0] if not series.dropna().empty else np.nan

# %%
df['Person_Age_Days'] = df.groupby('Person_ID')['Person_Age_Days'].transform(first_non_null)

# %%
#to check functionality
df[df['Person_ID']==1184868][['Person_ID', 'Person_Age_Days']]
# Out:
#       Person_ID  Person_Age_Days
# 3664    1184868           9115.0
# 3666    1184868           9115.0
# 3668    1184868           9115.0
# 3669    1184868           9115.0
# 3670    1184868           9115.0
# 3672    1184868           9115.0

# %%
# For ease of calculation, we will convert person_age_days to person_age_years and round it to 0 decimal
df['Person_Age_Years'] = np.floor(df['Person_Age_Days'] / 365)

# %% [markdown]
# ### 3. For team events, the final rank will be 1 for all team members but the medal given will be just 1.

# %%
df[(df['Event_Name']=='Team') & (df['Final Rank']==1) & (df['Event_ID']==200010983)]
# Out:
#       Competition_Name        Competitor Event_Gender   Event_ID Event_Name  \
# 1        Olympic Games       A'Ja Wilson        Women  200010983       Team
# 2411     Olympic Games      Ariel Atkins        Women  200010983       Team
# 3458     Olympic Games   Breanna Stewart        Women  200010983       Team
# 3546     Olympic Games   Brittney Griner        Women  200010983       Team
# 4210     Olympic Games      Chelsea Gray        Women  200010983       Team
# 5590     Olympic Games     Diana Taurasi        Women  200010983       Team
# 10332    Olympic Games       Jewell Loyd        Women  200010983       Team
# 16572    Olympic Games  Napheesa Collier        Women  200010983       Team
# 20687    Olympic Games    Skylar Diggins        Women  200010983       Team
# 21110    Olympic Games          Sue Bird        Women  200010983       Team
# 21297    Olympic Games     Sylvia Fowles        Women  200010983       Team
# 21949    Olympic Games      Tina Charles        Women  200010983       Team
# 22401    Olympic Games     United States        Women  200010983       Team
#
#        Sport_Name  NOC       NOC_Name  Person_ID Result Result_Type  Sport_ID  \
# 1      Basketball  USA  United States    1192461    NaN         NaN       107
# 2411   Basketball  USA  United States    1865314    NaN         NaN       107
# 3458   Basketball  USA  United States     958020    NaN         NaN       107
# 3546   Basketball  USA  United States    1025574    NaN         NaN       107
# 4210   Basketball  USA  United States    1865479    NaN         NaN       107
# 5590   Basketball  USA  United States     558154    NaN         NaN       107
# 10332  Basketball  USA  United States    1500997    NaN         NaN       107
# 16572  Basketball  USA  United States    1303905    NaN         NaN       107
# 20687  Basketball  USA  United States     814217    NaN         NaN       107
# 21110  Basketball  USA  United States     447561    NaN         NaN       107
# 21297  Basketball  USA  United States     728353    NaN         NaN       107
# 21949  Basketball  USA  United States     898742    NaN         NaN       107
# 22401  Basketball  USA  United States         -1    NaN         NaN       107
#
#          Team_ID                                          Team_Mbrs  \
# 1      100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 2411   100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 3458   100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 3546   100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 4210   100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 5590   100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 10332  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 16572  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 20687  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 21110  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 21297  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 21949  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
# 22401  100000499  Atkins, Ariel; Bird, Sue; Charles, Tina; Diggi...
#
#        Person_Age_Days  Final Rank  Person_Age_Years
# 1                  NaN         1.0               NaN
# 2411               NaN         1.0               NaN
# 3458               NaN         1.0               NaN
# 3546               NaN         1.0               NaN
# 4210               NaN         1.0               NaN
# 5590               NaN         1.0               NaN
# 10332              NaN         1.0               NaN
# 16572              NaN         1.0               NaN
# 20687              NaN         1.0               NaN
# 21110              NaN         1.0               NaN
# 21297              NaN         1.0               NaN
# 21949              NaN         1.0               NaN
# 22401              NaN         1.0               NaN

# %% [markdown]
# ##### To ensure we get a correct count of medals won, we will create a new column

# %% [markdown]
# ##### The assign_medal_count function sorts a group by 'Final Rank' and assigns a unique medal count to each unique rank, and sets duplicate ranks to 0. This ensures each unique rank is counted once in the 'Medal_count' column.

# %%
def assign_medal_count(group):
    group = group.sort_values(by='Final Rank')
    medal_count = []
    seen_ranks = set()
    for rank in group['Final Rank']:
        if rank not in seen_ranks:
            medal_count.append(rank)
            seen_ranks.add(rank)
        else:
            medal_count.append(0)
    group['Medal_count'] = medal_count
    return group

df_new = df.groupby(['Event_ID', 'Team_ID']).apply(assign_medal_count).reset_index(drop=True)

# %%
#checking the functionality
df_new[(df_new['Event_Name']=='Team') & (df_new['Final Rank']==1) & (df_new['Team_ID']==100021052)]
# Out:
#        Competition_Name                 Competitor Event_Gender   Event_ID  \
# 18246  Paralympic Games           Alexis Shifflett        Women  200011562
# 18247  Paralympic Games              Bethany Zummo        Women  200011562
# 18248  Paralympic Games               Emma Schieck        Women  200011562
# 18249  Paralympic Games           Heather Erickson        Women  200011562
# 18250  Paralympic Games  Jillian Kathleen Williams        Women  200011562
# 18251  Paralympic Games               Kaleo Maclay        Women  200011562
# 18252  Paralympic Games           Kathryn Holloway        Women  200011562
# 18253  Paralympic Games               Lora Webster        Women  200011562
# 18254  Paralympic Games           Monique Burkland        Women  200011562
# 18255  Paralympic Games              Nicole Nieves        Women  200011562
# 18256  Paralympic Games                Tia Edwards        Women  200011562
# 18257  Paralympic Games              United States        Women  200011562
# 18258  Paralympic Games              Whitney Dosty        Women  200011562
#
#       Event_Name          Sport_Name  NOC       NOC_Name  Person_ID Result  \
# 18246       Team  Sitting Volleyball  USA  United States    1274283    NaN
# 18247       Team  Sitting Volleyball  USA  United States    1065736    NaN
# 18248       Team  Sitting Volleyball  USA  United States    2206927    NaN
# 18249       Team  Sitting Volleyball  USA  United States    1035874    NaN
# 18250       Team  Sitting Volleyball  USA  United States    1825264    NaN
# 18251       Team  Sitting Volleyball  USA  United States    1065533    NaN
# 18252       Team  Sitting Volleyball  USA  United States    1274377    NaN
# 18253       Team  Sitting Volleyball  USA  United States     681496    NaN
# 18254       Team  Sitting Volleyball  USA  United States    1066175    NaN
# 18255       Team  Sitting Volleyball  USA  United States    1274387    NaN
# 18256       Team  Sitting Volleyball  USA  United States    1421201    NaN
# 18257       Team  Sitting Volleyball  USA  United States         -1    NaN
# 18258       Team  Sitting Volleyball  USA  United States    1119883    NaN
#
#       Result_Type  Sport_ID    Team_ID  \
# 18246         NaN       520  100021052
# 18247         NaN       520  100021052
# 18248         NaN       520  100021052
# 18249         NaN       520  100021052
# 18250         NaN       520  100021052
# 18251         NaN       520  100021052
# 18252         NaN       520  100021052
# 18253         NaN       520  100021052
# 18254         NaN       520  100021052
# 18255         NaN       520  100021052
# 18256         NaN       520  100021052
# 18257         NaN       520  100021052
# 18258         NaN       520  100021052
#
#                                                Team_Mbrs  Person_Age_Days  \
# 18246  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18247  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18248  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18249  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18250  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18251  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18252  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18253  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18254  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18255  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18256  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18257  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
# 18258  Webster, Lora; Erickson, Heather; Maclay, Kale...              NaN
#
#        Final Rank  Person_Age_Years  Medal_count
# 18246         1.0               NaN          1.0
# 18247         1.0               NaN          0.0
# 18248         1.0               NaN          0.0
# 18249         1.0               NaN          0.0
# 18250         1.0               NaN          0.0
# 18251         1.0               NaN          0.0
# 18252         1.0               NaN          0.0
# 18253         1.0               NaN          0.0
# 18254         1.0               NaN          0.0
# 18255         1.0               NaN          0.0
# 18256         1.0               NaN          0.0
# 18257         1.0               NaN          0.0
# 18258         1.0               NaN          0.0

# %%
df_new.to_csv('clean_data.csv', index=False)
